# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#race background" data-toc-modified-id="比赛背景-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>game background</a></span></li><li><span><a href="#data and specific goals" data-toc-modified-id="Data and Specific Objectives-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Data and Specific Goals</a></span></li><li><span><a href="#Implementation process" data-toc-modified-id="Implementation Process-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Implementation process</a></span></li><li><span><a href="#Code" data-toc-modified-id="Code Implementation-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Code</a></span><ul class="toc-item"><li><span><a href="#导入相关包" data-toc-modified-id="导入相关包-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Import related packages</a></span></li><li><span><a href="#读取数据" data-toc-modified-id="读取数据-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>read data</a></span></li><li><span><a href="#数据预处理与特征工程" data-toc-modified-id="数据预处理与特征工程-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Data Preprocessing and Feature Engineering</a></span><ul class="toc-item"><li><span><a href="#日期数据处理及特征类别转换" data-toc-modified-id="日期数据处理及特征类别转换-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Date data processing and feature category conversion</a></span></li><li><span><a href="#缺失值分析" data-toc-modified-id="缺失值分析-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Missing value analysis</a></span></li><li><span><a href="#异常值处理" data-toc-modified-id="异常值处理-4.3.3"><span class="toc-item-num">4.3.3&nbsp;&nbsp;</span>Outlier handling</a></span></li><li><span><a href="#可视化分析" data-toc-modified-id="可视化分析-4.3.4"><span class="toc-item-num">4.3.4&nbsp;&nbsp;</span>visual analysis</a></span></li><li><span><a href="#目标变量分析" data-toc-modified-id="目标变量分析-4.3.5"><span class="toc-item-num">4.3.5&nbsp;&nbsp;</span>target variable analysis</a></span></li><li><span><a href="#运用随机森林模型填充-windspeed-特征中的零值" data-toc-modified-id="运用随机森林模型填充-windspeed-特征中的零值-4.3.6"><span class="toc-item-num">4.3.6&nbsp;&nbsp;</span>Fill in zero values in windspeed features using a random forest model</a></span></li></ul></li><li><span><a href="#模型的建立与求解" data-toc-modified-id="模型的建立与求解-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Model building and solving</a></span><ul class="toc-item"><li><span><a href="#准备数据" data-toc-modified-id="准备数据-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>prepare data</a></span></li><li><span><a href="#基本模型" data-toc-modified-id="基本模型-4.4.2"><span class="toc-item-num">4.4.2&nbsp;&nbsp;</span>basic model</a></span><ul class="toc-item"><li><span><a href="#线性回归(LinearRegression)" data-toc-modified-id="线性回归(LinearRegression)-4.4.2.1"><span class="toc-item-num">4.4.2.1&nbsp;&nbsp;</span>linear regression(LinearRegression)</a></span></li><li><span><a href="#逻辑回归(LogisticRegression)" data-toc-modified-id="逻辑回归(LogisticRegression)-4.4.2.2"><span class="toc-item-num">4.4.2.2&nbsp;&nbsp;</span>logistic regression(LogisticRegression)</a></span></li><li><span><a href="#套索回归(LassoRegression)" data-toc-modified-id="套索回归(LassoRegression)-4.4.2.3"><span class="toc-item-num">4.4.2.3&nbsp;&nbsp;</span>套索回归(LassoRegression)</a></span></li><li><span><a href="#岭回归(RidgeRegression)" data-toc-modified-id="岭回归(RidgeRegression)-4.4.2.4"><span class="toc-item-num">4.4.2.4&nbsp;&nbsp;</span>岭回归(RidgeRegression)</a></span></li><li><span><a href="#核岭回归(KernelRidge)" data-toc-modified-id="核岭回归(KernelRidge)-4.4.2.5"><span class="toc-item-num">4.4.2.5&nbsp;&nbsp;</span>核岭回归(KernelRidge)</a></span></li><li><span><a href="#弹性网络(ElasticNet)" data-toc-modified-id="弹性网络(ElasticNet)-4.4.2.6"><span class="toc-item-num">4.4.2.6&nbsp;&nbsp;</span>弹性网络(ElasticNet)</a></span></li><li><span><a href="#支持向量机(SVR,-Support-Vector-Regression)" data-toc-modified-id="支持向量机(SVR,-Support-Vector-Regression)-4.4.2.7"><span class="toc-item-num">4.4.2.7&nbsp;&nbsp;</span>支持向量机(SVR, Support Vector Regression)</a></span></li><li><span><a href="#K近邻回归(KNeighborsRegressor)" data-toc-modified-id="K近邻回归(KNeighborsRegressor)-4.4.2.8"><span class="toc-item-num">4.4.2.8&nbsp;&nbsp;</span>K近邻回归(KNeighborsRegressor)</a></span></li><li><span><a href="#决策树回归(DecisionTreeRegressor)" data-toc-modified-id="决策树回归(DecisionTreeRegressor)-4.4.2.9"><span class="toc-item-num">4.4.2.9&nbsp;&nbsp;</span>决策树回归(DecisionTreeRegressor)</a></span></li><li><span><a href="#极端随机树(ExtraTreesRegressor)" data-toc-modified-id="极端随机树(ExtraTreesRegressor)-4.4.2.10"><span class="toc-item-num">4.4.2.10&nbsp;&nbsp;</span>极端随机树(ExtraTreesRegressor)</a></span></li><li><span><a href="#装袋法(BaggingRegressor)" data-toc-modified-id="装袋法(BaggingRegressor)-4.4.2.11"><span class="toc-item-num">4.4.2.11&nbsp;&nbsp;</span>装袋法(BaggingRegressor)</a></span></li><li><span><a href="#随机森林(RandomForestRegressor)" data-toc-modified-id="随机森林(RandomForestRegressor)-4.4.2.12"><span class="toc-item-num">4.4.2.12&nbsp;&nbsp;</span>随机森林(RandomForestRegressor)</a></span></li><li><span><a href="#AdaBoost-(AdaBoostRegressor)" data-toc-modified-id="AdaBoost-(AdaBoostRegressor)-4.4.2.13"><span class="toc-item-num">4.4.2.13&nbsp;&nbsp;</span>AdaBoost (AdaBoostRegressor)</a></span></li><li><span><a href="#GBRT-(GradientBoostingRegressor)" data-toc-modified-id="GBRT-(GradientBoostingRegressor)-4.4.2.14"><span class="toc-item-num">4.4.2.14&nbsp;&nbsp;</span>GBRT (GradientBoostingRegressor)</a></span></li><li><span><a href="#XGBoost-(XGBRegressor)" data-toc-modified-id="XGBoost-(XGBRegressor)-4.4.2.15"><span class="toc-item-num">4.4.2.15&nbsp;&nbsp;</span>XGBoost (XGBRegressor)</a></span></li><li><span><a href="#LightGBM-(LGBMRegressor)" data-toc-modified-id="LightGBM-(LGBMRegressor)-4.4.2.16"><span class="toc-item-num">4.4.2.16&nbsp;&nbsp;</span>LightGBM (LGBMRegressor)</a></span></li></ul></li><li><span><a href="#模型融合-Stacking" data-toc-modified-id="模型融合-Stacking-4.4.3"><span class="toc-item-num">4.4.3&nbsp;&nbsp;</span>模型融合 Stacking</a></span></li><li><span><a href="#提交最终预测结果" data-toc-modified-id="提交最终预测结果-4.4.4"><span class="toc-item-num">4.4.4&nbsp;&nbsp;</span>提交最终预测结果</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# <h1><font size=6>共享单车需求预测</font><span class="tocSkip"></span></h1>
#
# **<font size=3>[Bike-Sharing][1][-Demand][2]</font>**
#
# [1]: https://www.kaggle.com/competitions/bike-sharing-demand
# [2]: https://www.kaggle.com/code/viveksrinivasan/eda-ensemble-model-top-10-percentile/notebook

# %% [markdown]
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# # Game background

# %% [markdown]
# <font size=3>&emsp;&emsp; In the shared bicycle system network covering the whole city, users can rent and return bicycles by themselves. Currently, there are more than 500 bike-sharing systems around the world. The data generated by these systems clearly records information such as **user rental time, departure and end locations**, and acts as a sensor network that can be used to study urban traffic behavior. </font>
#
# <font size=3>&emsp;&emsp;In this competition, you are asked to use historical data, including weather conditions, to predict the rental demand of Washington's shared bike system. </font>

# %% [markdown]
# # Data and specific goals

# %% [markdown]
# <font size=3> &emsp;&emsp;**★ file description** </font>
#
# <font size=3>&emsp;&emsp;&emsp;&emsp;**train.csv** - contains the training set of target variables \
#     &emsp;&emsp;&emsp;&emsp;**test.csv** - test set without target variable \
#     &emsp;&emsp;&emsp;&emsp;**sampleSubmission.csv** - sample submission file in the correct format</font>
#
# <font size=3>&emsp;&emsp;**★ data field** </font>
#
# <font size=3>&emsp;&emsp;&emsp;&emsp;The official website provides an hourly car rental data spanning two years, in which **training set** provides the data and usage of the first 19 days of each month,* *test set** provided after the 20th to the end of the month \
#     &emsp;&emsp; data. Take a look at the specific fields:</font>
#
# ![variable preview image.jpg](attachment:0377daab-1271-45bf-8461-dc6952aae0ff.jpg)
# ![variable meaning.jpg](attachment:d7596896-9835-459c-ad04-a673a16e5856.jpg)

# %% [markdown]
# <font size=3>&emsp;&emsp;**★ Final goal: Use information available before the rental period to predict hourly bike usage for the test set. ** </font>
#
# <font size=3>&emsp;&emsp;**★ Evaluation index: Root Mean Squared Logarithmic Error (RMSLE) is required to evaluate the quality of the model. Its mathematical formula is: **</font>
#
# $$ RMSLE = \sqrt{\frac{1}{n} \sum_{i=1}^n [\log(p_i + 1) - \log(a_i + 1)]^2} $$
#
# <font size=3>&emsp;&emsp;&emsp;Among them, $n$ is the number of samples in the test set, $p_i$ is the test value, and $a_i$ is the actual value. The smaller the root mean square error, the better the fitting effect of the data, and the closer the test value is to the actual value. </font>

# %% [markdown]
# # Implementation process

# %% [markdown]
# ![实施流程图(2).jpg](attachment:9bef5ffe-0c61-4f86-81be-46fa04f01a80.jpg)

# %% [markdown]
# # 代码实现

# %% [markdown]
# ## 导入相关包

# %%
# 数据处理
import numpy as np
import pandas as pd 
import calendar
from datetime import datetime
from scipy import stats
from scipy.stats import norm

# 数据可视化
import matplotlib.pyplot as plt
import seaborn as sns 

# 模型
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression, Ridge, Lasso, ElasticNet
from sklearn.kernel_ridge import KernelRidge
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor, ExtraTreeRegressor
from sklearn.ensemble import BaggingRegressor, RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor, GradientBoostingRegressor
from sklearn.ensemble import StackingRegressor
import xgboost as xgb
#import lightgbm as lgb
from sklearn.model_selection import GridSearchCV
from sklearn import metrics

# 杂项
import warnings

pd.options.mode.chained_assignment = None
warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# ## read data

# %%
train = pd.read_csv("Data/train.csv", parse_dates=True)  # parse_dates将csv中的时间字符串转换成日期格式
test = pd.read_csv("Data/test.csv", parse_dates=True)

# %%
train.shape, test.shape
# Out:
# ((10886, 12), (6493, 9))

# %%
train.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
test.head()
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1  2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2  2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3  2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4  2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed
# 0        56    26.0027
# 1        56     0.0000
# 2        56     0.0000
# 3        56    11.0014
# 4        56    11.0014

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB

# %% [markdown]
# ## Data preprocessing and feature engineering

# %% [markdown]
# ### Date data processing and feature category conversion

# %%
for df in [train, test]:
    # 日期数据处理
    format = '%Y-%m-%d %H:%M:%S'
    df['date'] = pd.to_datetime(df['datetime'], format=format)
    df['month'] = df.date.dt.month
    df['day'] = df.date.dt.day
    df['weekday'] = df.date.dt.weekday
    df['hour'] = df.date.dt.hour
    df.drop(['date'], axis=1, inplace=True)
    # 转换部分特征为类别特征
    df['month'] = df.month.apply(lambda x: calendar.month_name[x])
    df['weekday'] = df.weekday.apply(lambda x: calendar.day_name[x])
    df["season"] = df.season.map({1: "Spring", 2 : "Summer", 3 : "Fall", 4 :"Winter" })
    df["weather"] = df.weather.map({1: "Sunny", 2:"Cloudy", 3:"Light Rain", 4:"Heavy Rain"})
    # 将类别特征强制转换为Category
    category_varlist = ["month", "day", "weekday", "hour", "season", "holiday", "workingday", "weather"]
    for var in category_varlist:
        df[var] = df[var].astype("category")

# %% [markdown]
# ### Missing value analysis

# %%
print("The number of missing values ​​in the training set and：%i" % (train.isnull().sum().sum()))
print("The number of missing values ​​in the test set and：%i" % (test.isnull().sum().sum()))
# Out:
# The number of missing values ​​in the training set and：0
# The number of missing values ​​in the test set and：0

# %% [markdown]
# ### Outlier handling

# %% [markdown]
# - Visualize the target variable Count with a boxplot

# %%
plt.figure(figsize=(6, 6))
sns.boxplot(data=train, y="count")
plt.title("Box Plot On Count")
# Out:
# Text(0.5, 1.0, 'Box Plot On Count')

# %% [markdown]
# - Use the 3σ principle to remove outliers

# %%
# Use the 3sigma principle to remove outliers
print ("Training set size before removing outliers：", train.shape)
train = train[abs(train["count"] - train["count"].mean()) <= (3 * train["count"].std())]
print ("Training set size after removing outliers：", train.shape)
# Out:
# Training set size before removing outliers： (10886, 16)
# Training set size after removing outliers： (10739, 16)

# %% [markdown]
# ### Visual Analysis

# %% [markdown]
# - **First visualize the 8 category features**
#
#     * **Influence of different time periods on usage ( hour → count )** \
#     Figure 1: In different time periods of the day, the usage of shared bicycles varies significantly, and it is significantly more at 8 o'clock and 16-19 o'clock than other time points. The reason is that this period is the peak period of commuting; 5 o'clock is obviously lower than other time points, and the reason considered is that it is sleep time during this period.
#
#     * **The impact of the day of the week on usage ( weekday → count )** \
#     Figure 2: The day of the week does not have much impact on total bike usage.
#
#     * ** Which day of the month affects usage ( day → count )** \
#     Figure 3: The day of the month does not have much impact on total bike usage either.
#
#     * **Influence of month on usage ( month → count )** \
#     Figure 4: The use of shared bicycles from November to April will be a little less than in other months, which may be due to seasonal reasons. Winter and spring are too cold to reduce the use of bicycles. So next, let's observe the impact of seasons on usage for verification.
#
#   * **Influence of season on usage ( season → count )** \
#     Figure 5: It can be seen that the use of winter and spring is relatively small compared to summer and autumn, which is mutually confirmed with the conclusions generated in the above months.
#
#     * **Influence of holidays on usage (holiday → count)** \
#     Figure 6: Whether there are holidays or not has little impact on the total bicycle usage.
#
#     * **Influence of working days on usage ( workingday → count )** \
#     Figure 7: Whether it is a working day or not has little effect on the total bicycle usage.
#
#     * **Influence of weather on usage ( weather → count )** \
#     Figure 8: The impact of weather on bicycles is basically in line with the actual situation in daily life. The use of bicycles decreases on rainy days, and almost no one uses shared bicycles during heavy rain.

# %%
weekday_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
month_order = ['January', 'February', 'March', 'April', 'May', 'June',
               'July', 'August', 'September', 'October', 'November', 'December']
season_order = ['Spring', 'Summer', 'Fall', 'Winter']
weather_order = ['Sunny', 'Cloudy', 'Light Rain', 'Heavy Rain']

fig, axes = plt.subplots(figsize=(15, 20), nrows=4, ncols=2)
sns.boxplot(data=train, y="count", x="hour", ax=axes[0][0])
sns.boxplot(data=train, y="count", x="weekday", order=weekday_order, ax=axes[0][1])
sns.boxplot(data=train, y="count", x="day", ax=axes[1][0])
sns.boxplot(data=train, y="count", x="month", order=month_order, ax=axes[1][1])
sns.boxplot(data=train, y="count", x="season", order=season_order, ax=axes[2][0])
sns.boxplot(data=train, y="count", x="holiday", ax=axes[2][1])
sns.boxplot(data=train, y="count", x="workingday", ax=axes[3][0])
sns.stripplot(data=train, y="count", x="weather", order=weather_order, ax=axes[3][1])

axes[0][0].set(xlabel='Hour', ylabel='Count', title="Boxplot On Count Across Hour")
axes[0][1].set(xlabel='Weekday', ylabel='Count', title="Boxplot On Count Across Weekday")
axes[1][0].set(xlabel='Day', ylabel='Count', title="Boxplot On Count Across Day")
axes[1][1].set(xlabel='Month', ylabel='Count', title="Boxplot On Count Across Month")
axes[2][0].set(xlabel='Season', ylabel='Count', title="Boxplot On Count Across Season")
axes[2][1].set(xlabel='Holiday', ylabel='Count', title="Boxplot On Count Across Holiday")
axes[3][0].set(xlabel='Workingday', ylabel='Count', title="Boxplot On Count Across Workingday")
axes[3][1].set(xlabel='Weather', ylabel='Count', title="Stripplot On Count Across Weather")
plt.tight_layout()

# %% [markdown]
# - **Secondly, the two fields are combined with visual analysis**
#
#     * **The impact of the week on the bicycle usage in different time periods ( hour + weekday → count )** \
#     Figure 1: Compared with Monday to Friday, Saturday and Sunday have significantly different impacts on bicycle usage in different time periods.
#
#     * **The impact of date on bicycle usage in different time periods ( hour + day → count )** \
#     Figure 2: The impact of different dates on bicycle usage in different time periods, showing certain differences between the two peaks.
#
#     * **Influence of holidays on bicycle usage in different time periods ( hour + holiday → count )** \
#     Figure 3: Compared with holidays, non-holidays show greater bicycle usage during rush hours for work and get off work.
#
#     * **The impact of working days on bicycle usage in different time periods ( hour + workingday → count )** \
#     Figure 4: Similarly, compared with non-working days, working days show greater bicycle usage during the peak hours of going to and from get off work; non-working days have higher bicycle usage from 11:00 to 17:00, guessing it may be Go out to eat or play.

# %%
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False
plt.figure(figsize=(14, 10))
plt.subplot(221)
sns.pointplot(x="hour", y="count", hue="weekday", hue_order=weekday_order, ci=None, data=train)
plt.title("星期对不同时间段单车使用量的影响")
plt.subplot(222)
sns.pointplot(x="hour", y="count", hue="day", ci=None, data=train)
plt.title("日期对不同时间段单车使用量的影响")
plt.subplot(223)
sns.pointplot(x="hour", y="count", hue="holiday", ci=None, data=train)
plt.title("节假日对不同时间段单车使用量的影响")
plt.subplot(224)
sns.pointplot(x="hour", y="count", hue="workingday", ci=None, data=train)
plt.title("工作日对不同时间段单车使用量的影响")
plt.tight_layout()

# %% [markdown]
# - **Then, visualize 6 of the numerical features**
#
#     * **Influence of actual temperature on usage ( temp → count )** \
#     Figure 1: When the actual temperature is greater than 10 degrees, the temperature change has little effect on the bicycle usage; when the actual temperature is lower than 10 degrees, the bicycle usage is significantly reduced.
#
#     * **Influence of body temperature on usage ( atemp → count )** \
#     Figure 2: The impact of the perceived temperature on the usage of bicycles is consistent with that of the actual temperature. When the perceived temperature is greater than 10 degrees, the temperature change has little effect on the usage of bicycles; when the perceived temperature is lower than 10 degrees, the bicycle usage Usage has been significantly reduced.
#
#     * **Influence of humidity on usage ( humidity → count )** \
#     Figure 3: On the whole, the impact of humidity on bicycle usage is not very great, and the usage decreases when the humidity is higher than 90%, which may be because it is already raining when the humidity reaches 90%.
#
#     * **Influence of wind speed on usage ( windspeed → count )** \
#     Figure 4: On the whole, the wind speed does not have much impact on the bicycle usage. When the wind speed is close to 40 and above, the bicycle usage decreases, and the data points with the wind speed exceeding 50 are also relatively small. When the wind speed is 0, use The high volume may be due to null padding.

# %%
plt.figure(figsize=(18, 8))
plt.subplot(221)
sns.regplot(x="temp", y="count", data=train)
plt.title("Effect of actual temperature on bicycle usage in different time periods")
plt.subplot(222)
sns.regplot(x="atemp", y="count", data=train)
plt.title("Effect of body temperature on bicycle usage in different time periods")
plt.subplot(223)
sns.regplot(x="humidity", y="count", data=train)
plt.title("Effect of humidity on bicycle usage in different time periods")
plt.subplot(224)
sns.regplot(x="windspeed", y="count", data=train)
plt.title("Effect of wind speed on bicycle usage in different time periods")
plt.tight_layout()

# %% [markdown]
# -
#     * **Influence of registered users and non-registered users on usage ( registered → count & casual → count )** \
#     As can be seen from the figure below, the usage of registered users accounts for the vast majority of the total usage of bicycles, and the trend is consistent with the trend of total usage, while the usage of non-registered users does not change much at different times of the day. It shows that the usage is mainly determined by registered users, and registered users are more sticky.

# %%
melt_df = pd.melt(train[["hour", "casual", "registered", "count"]], id_vars=["hour"], value_vars=["casual", "registered", "count"])
melt_df.head()
# Out:
#   hour variable  value
# 0    0   casual      3
# 1    1   casual      8
# 2    2   casual      5
# 3    3   casual      3
# 4    4   casual      0

# %%
melt_group_df = melt_df.groupby(["hour", "variable"])["value"].mean().reset_index()
melt_group_df.head()
# Out:
#   hour    variable      value
# 0    0      casual  10.312088
# 1    0       count  55.138462
# 2    0  registered  44.826374
# 3    1      casual   6.513216
# 4    1       count  33.859031

# %%
plt.figure(figsize=(18, 6))
plt.subplot(121)
variable_order = ['casual', 'registered', 'count']
sns.pointplot(x="hour", y="value", hue="variable", hue_order=variable_order, data=melt_group_df)
plt.subplot(122)
sns.pointplot(x="hour", y="value", hue="variable", hue_order=variable_order, data=melt_df)
# Out:
# <AxesSubplot:xlabel='hour', ylabel='value'>

# %% [markdown]
# - **Finally, draw the correlation matrix heatmap between the various numerical features**
#
#     A common way to understand how target variables are affected by numerical features is to find the correlation matrix between them, plotting a heatmap of the correlation matrix between count and [temp, atemp, humidity, windspeed, casual, registered].
#     - **humidity is negatively correlated with count, other features like temp are negatively correlated with count. **
#     - There is a strong correlation between **temp and atemp, if both are included in the model, it will cause multicollinearity problems, so one of the features must be deleted. We remove the atemp feature because it has a weaker correlation with count than temp. **
#     - **casual and registered are also not considered, because they are essentially leaky variables, and their values ​​​​are not available in the test set, so they need to be removed during model building. **
# - In this way, we mainly consider **"temp" "humidity" "windspeed"** these 3 numerical features when modeling.

# %%
corr_df = train[["temp", "atemp", "humidity", "windspeed", "casual", "registered", "count"]].corr()
mask = np.array(corr_df)
mask[np.tril_indices_from(mask)] = False  # mask = np.zeros_like(corr) # mask[np.triu_indices_from(mask)] = True
plt.figure(figsize=(10, 8))
sns.heatmap(corr_df, mask=mask, vmax=0.8, square=True, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Target variable analysis

# %% [markdown]
# - As can be seen from the figure below, the target variable count has a right-skewed distribution. Since most machine learning techniques require the dependent variable to be normally distributed, variable transformation is required. One possible solution is to log-transform the count variable after removing outlier data points. The transformed data looks much better, approximately following a normal distribution.

# %%
fig, ax = plt.subplots(ncols=2, nrows=2, figsize=(12, 9))
(mu, sigma) = norm.fit(train['count'])
sns.distplot(train['count'], fit=norm, ax=ax[0][0])
ax[0][0].legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)], loc='best')
ax[0][0].set_title("Count distribution before logarithmic transformation")
stats.probplot(train['count'], plot=ax[0][1])

train['count'] = np.log(train['count'])
(mu, sigma) = norm.fit(train['count'])
sns.distplot(train['count'], fit=norm, ax=ax[1][0])
ax[1][0].legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)], loc='best')
ax[1][0].set_title("Count distribution after logarithmic transformation")
stats.probplot(train['count'], plot=ax[1][1])
plt.tight_layout()

# %% [markdown]
# ### Use the random forest model to fill in the zero values in the windspeed feature

# %% [markdown]
# - From the above visual analysis, we know that the usage is high when the wind speed is 0, which may be caused by null filling. We know that there are 1297 0 values ​​​​through the unique value count, which is indeed a bit too much. Therefore, a random forest model is used here to fill in the zero values ​​in the windspeed feature.

# %%
train.windspeed.value_counts().iloc[:10]
# Out:
# 0.0000     1297
# 8.9981     1109
# 11.0014    1037
# 12.9980    1027
# 7.0015     1027
# 15.0013     942
# 6.0032      866
# 16.9979     807
# 19.0012     664
# 19.9995     486
# Name: windspeed, dtype: int64

# %% [markdown]
# - As can be seen from the above heat map of the correlation matrix, the three numerical features of temp, atemp, and humidity have a certain correlation with windspeed. Next, draw a boxplot to see if there is any relationship between category features and windspeed, so as to determine the random The features that should be included in the forest model. \
#     It can be seen that, except that holiday has almost no correlation with windspeed, other category features have a certain relationship with windspeed.

# %%
fig, axes = plt.subplots(figsize=(15, 20), nrows=4, ncols=2)
sns.boxplot(data=train, y="windspeed", x="hour", ax=axes[0][0])
sns.boxplot(data=train, y="windspeed", x="weekday", order=weekday_order, ax=axes[0][1])
sns.boxplot(data=train, y="windspeed", x="day", ax=axes[1][0])
sns.boxplot(data=train, y="windspeed", x="month", order=month_order, ax=axes[1][1])
sns.boxplot(data=train, y="windspeed", x="season", order=season_order, ax=axes[2][0])
sns.boxplot(data=train, y="windspeed", x="holiday", ax=axes[2][1])
sns.boxplot(data=train, y="windspeed", x="workingday", ax=axes[3][0])
sns.stripplot(data=train, y="windspeed", x="weather", order=weather_order, ax=axes[3][1])

axes[0][0].set(xlabel='Hour', ylabel='Windspeed', title="Boxplot On Windspeed Across Hour")
axes[0][1].set(xlabel='Weekday', ylabel='Windspeed', title="Boxplot On Windspeed Across Weekday")
axes[1][0].set(xlabel='Day', ylabel='Windspeed', title="Boxplot On Windspeed Across Day")
axes[1][1].set(xlabel='Month', ylabel='Windspeed', title="Boxplot On Windspeed Across Month")
axes[2][0].set(xlabel='Season', ylabel='Windspeed', title="Boxplot On Windspeed Across Season")
axes[2][1].set(xlabel='Holiday', ylabel='Windspeed', title="Boxplot On Windspeed Across Holiday")
axes[3][0].set(xlabel='Workingday', ylabel='Windspeed', title="Boxplot On Windspeed Across Workingday")
axes[3][1].set(xlabel='Weather', ylabel='Windspeed', title="Stripplot On Windspeed Across Weather")
plt.tight_layout()

# %% [markdown]
# - build a random forest model to fill the zero values ​​of windspeed

# %%
# Merge datasets
data_train = pd.read_csv("Data/train.csv", parse_dates=True)
data_test = pd.read_csv("Data/test.csv", parse_dates=True)
data = data_train.append(data_test).reset_index(drop=True)    # pd.concat([data_train, data_test]).reset_index(drop=True)

# Date data processing
format = '%Y-%m-%d %H:%M:%S'
data['date'] = pd.to_datetime(data['datetime'], format=format)
data['month'] = data.date.dt.month
data['day'] = data.date.dt.day
data['weekday'] = data.date.dt.weekday
data['hour'] = data.date.dt.hour

# Prepare Data to Fit Random Forest Model
windspeed_zero = data[data["windspeed"] == 0]
windspeed_nonzero = data[data["windspeed"] != 0]
rf_modeling = RandomForestRegressor()
wind_columns = ["hour", "weekday", "day", "month", "season", "workingday", "weather", "temp", "atemp", "humidity"]
rf_modeling.fit(windspeed_nonzero[wind_columns], windspeed_nonzero["windspeed"])

# Replace the original zero value with the predicted result
windspeed_pred = rf_modeling.predict(windspeed_zero[wind_columns])
windspeed_zero["windspeed"] = windspeed_pred
data = windspeed_nonzero.append(windspeed_zero).reset_index(drop=True)

# %%
# Divide the various characteristics
cat_feats = ["hour", "weekday", "day", "month", "season", "holiday", "workingday", "weather"]
num_feats = ["temp", "humidity", "windspeed"]
drop_feats = ["date", "atemp", "casual", "registered"]

# Coercing category features to Category
for var in cat_feats:
    data[var] = data[var].astype("category")   

data.drop(drop_feats, axis=1, inplace=True)

# %%
# Separate training and test sets
data_train = data[pd.notnull(data['count'])].sort_values(by=["datetime"]).reset_index(drop=True)
data_test = data[~pd.notnull(data['count'])].sort_values(by=["datetime"]).reset_index(drop=True)

# Target variable outlier processing and logarithmic transformation
data_train = data_train[abs(data_train["count"] - data_train["count"].mean()) <= (3 * data_train["count"].std())]
data_train['count'] = np.log(data_train['count'])
data_train.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## Model establishment and solution

# %% [markdown]
# ### Prepare data

# %%
# Indicate the training set features, corresponding labels and test set features
X_train = data_train[cat_feats + num_feats]
y_train = data_train["count"].values 
X_test = data_test[cat_feats + num_feats]
test_id = data_test["datetime"]
del train, test, data_train, data_test

# %%
# normalized data
scaler = RobustScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
X_train.shape, X_test.shape
# Out:
# ((10739, 11), (6493, 11))

# %%
# Divide the dataset
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.3)
X_train.shape, X_val.shape, X_test.shape
# Out:
# ((7517, 11), (3222, 11), (6493, 11))

# %% [markdown]
# ### Basic model

# %%
# Define the evaluation function
def rmsle(y, y_, convert_exp=True):
    if convert_exp:
        y = np.exp(y),
        y_ = np.exp(y_)
    log1 = np.nan_to_num(np.array([np.log(value + 1) for value in y]))
    log2 = np.nan_to_num(np.array([np.log(value + 1) for value in y_]))
    calc = (log1 - log2) ** 2
    return np.sqrt(np.mean(calc))

# %%
# Define the parameter function
def find_best_params(model, params, cv=5, n_jobs=-1, X_train=X_train, label=False):
    """
    Use grid search cross-validation to tune GridSearchCV and return the best model
    """
    rmsle_scorer = metrics.make_scorer(rmsle, greater_is_better=False) # 定义GridSearchCV的评分函数
    grid_cv = GridSearchCV(model, param_grid=params, scoring=rmsle_scorer, n_jobs=n_jobs, cv=cv, verbose=2)
    grid_cv.fit(X_train, y_train)
    if label:
        # Visualize the RMSLE score for each tuning
        fig, ax = plt.subplots(figsize=(12, 5))
        df = pd.DataFrame(grid_cv.cv_results_)
        df["alpha"] = df["params"].apply(lambda x: round(x["alpha"], 3))
        df["rmsle"] = df["mean_test_score"].apply(lambda x: -round(x, 4))
        sns.pointplot(data=df, x="alpha", y="rmsle", ax=ax)
    # output the best RMSLE score and the best parameters
    print("The best RMSLE score is: %.3f" % (-grid_cv.best_score_))
    print("The best parameters are: %s" % (grid_cv.best_params_))
    return grid_cv.best_estimator_

# %%
# Define the RMSLE result data frame
global i 
i = 0
def result_save(y_val, y_pred, label):
    result_df = pd.DataFrame({"Model": label, "RMSLE": rmsle(y_val, y_pred)}, index=[i])
    return result_df

# %% [markdown]
# #### Linear Regression(LinearRegression)

# %%
# Fit predictions using models
linear_model = LinearRegression()
linear_model.fit(X_train, y_train)
y_pred = linear_model.predict(X_val)
print("RMSLE For LinearRegression: %.3f" % (rmsle(y_val, y_pred)))

# Save RMSLE score
labels = []
label = "Linear Regression"
labels.append(label)
i = 0
result = result_save(y_val, y_pred, label)
result_df = result
del result
result_df
# Out:
# RMSLE For LinearRegression: 1.055
#                Model    RMSLE
# 0  Linear Regression  1.05494

# %% [markdown]
# #### 逻辑回归(LogisticRegression)

# %%
# 运用模型进行拟合预测
lr_model = LogisticRegression()
lr_model.fit(X_train, y_train.astype('int'))
y_pred = lr_model.predict(X_val)
print("RMSLE For Logistic Regression: %.3f" % (rmsle(y_val, y_pred)))

# 保存RMSLE得分
label = "Logistic Regression"
labels.append(label)
i += 1
result = result_save(y_val, y_pred, label)
result_df = result_df.append(result)
del result
result_df
# Out:
# RMSLE For Logistic Regression: 1.158
#                  Model     RMSLE
# 0    Linear Regression  1.054940
# 1  Logistic Regression  1.158177

# %% [markdown]
# #### 套索回归(LassoRegression)

# %%
# %%time
# 运用GridSearchCV调参
params = {
    'alpha': 1 / np.array([0.1, 1, 2, 3, 4, 10, 30, 100, 200, 300, 400, 800, 900, 1000])
}
lasso_model = find_best_params(Lasso(), params, label=True)
lasso_model
# Out:
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# The best RMSLE score is: 1.033
# The best parameters are: {'alpha': 0.01}
# CPU times: user 446 ms, sys: 293 ms, total: 738 ms
# Wall time: 1.57 s
# Lasso(alpha=0.01)

# %%
# 运用调参后的最佳模型进行拟合预测
lasso_model.fit(X_train, y_train)
y_pred = lasso_model.predict(X_val)
print("RMSLE For Lasso Regression: %.3f" % (rmsle(y_val, y_pred)))

# 保存RMSLE得分
label = "Lasso Regression"
labels.append(label)
i += 1
result = result_save(y_val, y_pred, label)
result_df = result_df.append(result)
del result
result_df
# Out:
# RMSLE For Lasso Regression: 1.054
#                  Model     RMSLE
# 0    Linear Regression  1.054940
# 1  Logistic Regression  1.158177
# 2     Lasso Regression  1.054427

# %% [markdown]
# #### 岭回归(RidgeRegression)

# %%
# %%time
# 运用GridSearchCV调参
params = {
    'alpha': [0.1, 1, 2, 3, 4, 10, 30, 100, 200, 300, 400, 800, 900, 1000]
}
ridge_model = find_best_params(Ridge(), params, label=True)
ridge_model
# Out:
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# The best RMSLE score is: 1.033
# The best parameters are: {'alpha': 100}
# CPU times: user 425 ms, sys: 240 ms, total: 664 ms
# Wall time: 133 ms
# Ridge(alpha=100)

# %%
# 运用调参后的最佳模型进行拟合预测
ridge_model.fit(X_train, y_train)
y_pred = ridge_model.predict(X_val)
print("RMSLE For Ridge Regression: %.3f" % (rmsle(y_val, y_pred)))

# 保存RMSLE得分
label = "Ridge Regression"
labels.append(label)
i += 1
result = result_save(y_val, y_pred, label)
result_df = result_df.append(result)
del result
result_df
# Out:
# RMSLE For Ridge Regression: 1.055
#                  Model     RMSLE
# 0    Linear Regression  1.054940
# 1  Logistic Regression  1.158177
# 2     Lasso Regression  1.054427
# 3     Ridge Regression  1.054669

# %% [markdown]
# #### 核岭回归(KernelRidge)

# %%
# %%time
# 运用GridSearchCV调参
params = {
    'alpha': [0.1, 1, 2, 3, 4, 10, 30, 100, 200, 300, 400, 800, 900, 1000]
}
kridge_model = find_best_params(KernelRidge(kernel='polynomial'), params)
kridge_model
# Out:
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# The best RMSLE score is: 0.816
# The best parameters are: {'alpha': 0.1}
# CPU times: user 15.4 s, sys: 1.58 s, total: 16.9 s
# Wall time: 1min 16s
# KernelRidge(alpha=0.1, kernel='polynomial')

# %%
# 运用调参后的最佳模型进行拟合预测
kridge_model.fit(X_train, y_train)
y_pred = kridge_model.predict(X_val)
print("RMSLE For KernelRidge Regression: %.3f" % (rmsle(y_val, y_pred)))

# 保存RMSLE得分
label = "KernelRidge Regression"
labels.append(label)
i += 1
result = result_save(y_val, y_pred, label)
result_df = result_df.append(result)
del result
result_df
# Out:
# RMSLE For KernelRidge Regression: 0.831
#                     Model     RMSLE
# 0       Linear Regression  1.054940
# 1     Logistic Regression  1.158177
# 2        Lasso Regression  1.054427
# 3        Ridge Regression  1.054669
# 4  KernelRidge Regression  0.830924

# %% [markdown]
# #### 弹性网络(ElasticNet)

# %%
# %%time
# 运用GridSearchCV调参
params = {
    'alpha': [0.1, 0.01, 0.005, 0.0025, 0.001],
    'l1_ratio': [0.1, 0.25, 0.5, 0.75, 0.8]
}
enet_model = find_best_params(ElasticNet(), params, label=False)
enet_model
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# The best RMSLE score is: 1.032
# The best parameters are: {'alpha': 0.01, 'l1_ratio': 0.5}
# CPU times: user 429 ms, sys: 243 ms, total: 673 ms
# Wall time: 176 ms
# ElasticNet(alpha=0.01)

# %%
# 运用调参后的最佳模型进行拟合预测
enet_model.fit(X_train, y_train)
y_pred = enet_model.predict(X_val)
print("RMSLE For ElasticNet Regression: %.3f" % (rmsle(y_val, y_pred)))

# 保存RMSLE得分
label = "ElasticNet Regression"
labels.append(label)
i += 1
result = result_save(y_val, y_pred, label)
result_df = result_df.append(result)
del result
result_df
# Out:
# RMSLE For ElasticNet Regression: 1.054
#                     Model     RMSLE
# 0       Linear Regression  1.054940
# 1     Logistic Regression  1.158177
# 2        Lasso Regression  1.054427
# 3        Ridge Regression  1.054669
# 4  KernelRidge Regression  0.830924
# 5   ElasticNet Regression  1.054424

# %% [markdown]
# #### 支持向量机(SVR, Support Vector Regression)

# %%
# 运用模型进行拟合预测
svr_model = SVR(C=0.01)
svr_model.fit(X_train, y_train)
y_pred = svr_model.predict(X_val)
print("RMSLE For SVR: %.3f" % (rmsle(y_val, y_pred)))

# 保存RMSLE得分
label = "SVR"
labels.append(label)
i += 1
result = result_save(y_val, y_pred, label)
result_df = result_df.append(result)
del result
result_df
# Out:
# RMSLE For SVR: 1.050
#                     Model     RMSLE
# 0       Linear Regression  1.054940
# 1     Logistic Regression  1.158177
# 2        Lasso Regression  1.054427
# 3        Ridge Regression  1.054669
# 4  KernelRidge Regression  0.830924
# 5   ElasticNet Regression  1.054424
# 6                     SVR  1.049624

# %% [markdown]
# #### K近邻回归(KNeighborsRegressor)

# %%
# %%time
# 运用GridSearchCV调参
params = {
    'n_neighbors': [*range(1, 11)]
}
knn_model = find_best_params(KNeighborsRegressor(), params)
knn_model
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# The best RMSLE score is: 0.877
# The best parameters are: {'n_neighbors': 9}
# CPU times: user 89.6 ms, sys: 16.3 ms, total: 106 ms
# Wall time: 460 ms
# KNeighborsRegressor(n_neighbors=9)

# %%
# 运用调参后的最佳模型进行拟合预测
knn_model.fit(X_train, y_train)
y_pred = knn_model.predict(X_val)
print("RMSLE For KNN: %.3f" % (rmsle(y_val, y_pred)))

# 保存RMSLE得分
label = "KNN"
labels.append(label)
i += 1
result = result_save(y_val, y_pred, label)
result_df = result_df.append(result)
del result
result_df
# Out:
# RMSLE For KNN: 0.869
#                     Model     RMSLE
# 0       Linear Regression  1.054940
# 1     Logistic Regression  1.158177
# 2        Lasso Regression  1.054427
# 3        Ridge Regression  1.054669
# 4  KernelRidge Regression  0.830924
# 5   ElasticNet Regression  1.054424
# 6                     SVR  1.049624
# 7                     KNN  0.869428

# %% [markdown]
# #### 决策树回归(DecisionTreeRegressor)

# %%
# 运用模型进行拟合预测
dtr_model = DecisionTreeRegressor()
dtr_model.fit(X_train, y_train)
y_pred = dtr_model.predict(X_val)
print("RMSLE For DecisionTreeRegressor: %.3f" % (rmsle(y_val, y_pred)))

# 保存RMSLE得分
label = "DecisionTreeRegressor"
labels.append(label)
i += 1
result = result_save(y_val, y_pred, label)
result_df = result_df.append(result)
del result
result_df
# Out:
# RMSLE For DecisionTreeRegressor: 0.529
#                     Model     RMSLE
# 0       Linear Regression  1.054940
# 1     Logistic Regression  1.158177
# 2        Lasso Regression  1.054427
# 3        Ridge Regression  1.054669
# 4  KernelRidge Regression  0.830924
# 5   ElasticNet Regression  1.054424
# 6                     SVR  1.049624
# 7                     KNN  0.869428
# 8   DecisionTreeRegressor  0.529171

# %% [markdown]
# #### 极端随机树(ExtraTreesRegressor)

# %%
# 运用模型进行拟合预测
etr_model = ExtraTreeRegressor()
etr_model.fit(X_train, y_train)
y_pred = etr_model.predict(X_val)
print("RMSLE For ExtraTreeRegressor: %.3f" % (rmsle(y_val, y_pred)))

# 保存RMSLE得分
label = "ExtraTreeRegressor"
labels.append(label)
i += 1
result = result_save(y_val, y_pred, label)
result_df = result_df.append(result)
del result
result_df
# Out:
# RMSLE For ExtraTreeRegressor: 0.541
#                     Model     RMSLE
# 0       Linear Regression  1.054940
# 1     Logistic Regression  1.158177
# 2        Lasso Regression  1.054427
# 3        Ridge Regression  1.054669
# 4  KernelRidge Regression  0.830924
# 5   ElasticNet Regression  1.054424
# 6                     SVR  1.049624
# 7                     KNN  0.869428
# 8   DecisionTreeRegressor  0.529171
# 9      ExtraTreeRegressor  0.540869

# %% [markdown]
# #### 装袋法(BaggingRegressor)

# %% [markdown]
# - [装袋法][1]
#
# [1]: https://blog.csdn.net/qq_36213518/article/details/54861930

# %%
# 运用模型进行拟合预测
bagging_model = BaggingRegressor()
bagging_model.fit(X_train, y_train)
y_pred = bagging_model.predict(X_val)
print("RMSLE For BaggingRegressor: %.3f" % (rmsle(y_val, y_pred)))

# 保存RMSLE得分
label = "BaggingRegressor"
labels.append(label)
i += 1
result = result_save(y_val, y_pred, label)
result_df = result_df.append(result)
del result
result_df
# Out:
# RMSLE For BaggingRegressor: 0.402
#                      Model     RMSLE
# 0        Linear Regression  1.054940
# 1      Logistic Regression  1.158177
# 2         Lasso Regression  1.054427
# 3         Ridge Regression  1.054669
# 4   KernelRidge Regression  0.830924
# 5    ElasticNet Regression  1.054424
# 6                      SVR  1.049624
# 7                      KNN  0.869428
# 8    DecisionTreeRegressor  0.529171
# 9       ExtraTreeRegressor  0.540869
# 10        BaggingRegressor  0.402155

# %% [markdown]
# #### 随机森林(RandomForestRegressor)

# %%
# 运用模型进行拟合预测
rf_model = RandomForestRegressor()
rf_model.fit(X_train, y_train)
y_pred = rf_model.predict(X_val)
print("RMSLE For RandomForestRegressor: %.3f" % (rmsle(y_val, y_pred)))

# 保存RMSLE得分
label = "RandomForestRegressor"
labels.append(label)
i += 1
result = result_save(y_val, y_pred, label)
result_df = result_df.append(result)
del result
result_df
# Out:
# RMSLE For RandomForestRegressor: 0.377
#                      Model     RMSLE
# 0        Linear Regression  1.054940
# 1      Logistic Regression  1.158177
# 2         Lasso Regression  1.054427
# 3         Ridge Regression  1.054669
# 4   KernelRidge Regression  0.830924
# 5    ElasticNet Regression  1.054424
# 6                      SVR  1.049624
# 7                      KNN  0.869428
# 8    DecisionTreeRegressor  0.529171
# 9       ExtraTreeRegressor  0.540869
# 10        BaggingRegressor  0.402155
# 11   RandomForestRegressor  0.377339

# %% [markdown]
# #### AdaBoost (AdaBoostRegressor)

# %%
# 运用模型进行拟合预测
ada_model = AdaBoostRegressor()
ada_model.fit(X_train, y_train)
y_pred = ada_model.predict(X_val)
print("RMSLE For AdaBoostRegressor: %.3f" % (rmsle(y_val, y_pred)))

# 保存RMSLE得分
label = "AdaBoostRegressor"
labels.append(label)
i += 1
result = result_save(y_val, y_pred, label)
result_df = result_df.append(result)
del result
result_df
# Out:
# RMSLE For AdaBoostRegressor: 0.717
#                      Model     RMSLE
# 0        Linear Regression  1.054940
# 1      Logistic Regression  1.158177
# 2         Lasso Regression  1.054427
# 3         Ridge Regression  1.054669
# 4   KernelRidge Regression  0.830924
# 5    ElasticNet Regression  1.054424
# 6                      SVR  1.049624
# 7                      KNN  0.869428
# 8    DecisionTreeRegressor  0.529171
# 9       ExtraTreeRegressor  0.540869
# 10        BaggingRegressor  0.402155
# 11   RandomForestRegressor  0.377339
# 12       AdaBoostRegressor  0.716580

# %% [markdown]
# #### GBRT (GradientBoostingRegressor)

# %%
# 运用模型进行拟合预测
gbrt_model = GradientBoostingRegressor()
gbrt_model.fit(X_train, y_train)
y_pred = gbrt_model.predict(X_val)
print("RMSLE For GBRT: %.3f" % (rmsle(y_val, y_pred)))

# 保存RMSLE得分
label = "GBRT"
labels.append(label)
i += 1
result = result_save(y_val, y_pred, label)
result_df = result_df.append(result)
del result
result_df
# Out:
# RMSLE For GBRT: 0.442
#                      Model     RMSLE
# 0        Linear Regression  1.054940
# 1      Logistic Regression  1.158177
# 2         Lasso Regression  1.054427
# 3         Ridge Regression  1.054669
# 4   KernelRidge Regression  0.830924
# 5    ElasticNet Regression  1.054424
# 6                      SVR  1.049624
# 7                      KNN  0.869428
# 8    DecisionTreeRegressor  0.529171
# 9       ExtraTreeRegressor  0.540869
# 10        BaggingRegressor  0.402155
# 11   RandomForestRegressor  0.377339
# 12       AdaBoostRegressor  0.716580
# 13                    GBRT  0.442394

# %% [markdown]
# #### XGBoost (XGBRegressor)

# %%
# 运用模型进行拟合预测
xgb_model = xgb.XGBRFRegressor(n_estimators=1000, max_depth=9)
xgb_model.fit(X_train, y_train)
y_pred = xgb_model.predict(X_val)
print("RMSLE For XGBoost: %.3f" % (rmsle(y_val, y_pred)))

# 保存RMSLE得分
label = "XGBoost"
labels.append(label)
i += 1
result = result_save(y_val, y_pred, label)
result_df = result_df.append(result)
del result
result_df
# Out:
# RMSLE For XGBoost: 0.421
#                      Model     RMSLE
# 0        Linear Regression  1.054940
# 1      Logistic Regression  1.158177
# 2         Lasso Regression  1.054427
# 3         Ridge Regression  1.054669
# 4   KernelRidge Regression  0.830924
# 5    ElasticNet Regression  1.054424
# 6                      SVR  1.049624
# 7                      KNN  0.869428
# 8    DecisionTreeRegressor  0.529171
# 9       ExtraTreeRegressor  0.540869
# 10        BaggingRegressor  0.402155
# 11   RandomForestRegressor  0.377339
# 12       AdaBoostRegressor  0.716580
# 13                    GBRT  0.442394
# 14                 XGBoost  0.420889

# %% [markdown]
# #### LightGBM (LGBMRegressor)

# %%
# 运用模型进行拟合预测
lgb_model = lgb.LGBMRegressor(n_estimators=1000)
lgb_model.fit(X_train, y_train)
y_pred = lgb_model.predict(X_val)
print("RMSLE For LightGBM: %.3f" % (rmsle(y_val, y_pred)))

# 保存RMSLE得分
label = "LightGBM"
labels.append(label)
i += 1
result = result_save(y_val, y_pred, label)
result_df = result_df.append(result)
del result
result_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/pd/16d8zcbx42z403yngy2y9m540000gn/T/ipykernel_65588/982616950.py in <module>
#       1 # 运用模型进行拟合预测
# ----> 2 lgb_model = lgb.LGBMRegressor(n_estimators=1000)
#       3 lgb_model.fit(X_train, y_train)
#       4 y_pred = lgb_model.predict(X_val)
#       5 print("RMSLE For LightGBM: %.3f" % (rmsle(y_val, y_pred)))
#
# NameError: name 'lgb' is not defined

# %% [markdown]
# - 16个模型的 RMSLE 得分汇总

# %%
result_df.sort_values(by='RMSLE', ascending=True)

# %% [markdown]
# ### 模型融合 Stacking

# %% [markdown]
# - Stacking模型融合

# %%
estimators = [('lgb', lgb.LGBMRegressor(n_estimators=1000)),
              ('rf', RandomForestRegressor()),
              ('bagging', BaggingRegressor()),
              ('xgb', xgb.XGBRFRegressor(n_estimators=1000, max_depth=9))
              ]
stacking_model = StackingRegressor(estimators=estimators,
                                   final_estimator=GradientBoostingRegressor(random_state=42))
stacking_model.fit(X_train, y_train)
y_pred = stacking_model.predict(X_val)
print("RMSLE For Stacking: %.4f" % (rmsle(y_val, y_pred)))

# %% [markdown]
# ### 提交最终预测结果

# %% [markdown]
# - 对最好的两个模型Stacking和LightGBM进行加权，并保存最终预测结果

# %%
stacking_pred = np.exp(stacking_model.predict(X_test))
lgb_pred = np.exp(lgb_model.predict(X_test))
ensemble = stacking_pred * 0.60 + lgb_pred * 0.40
ensemble_count = ensemble.round(0).astype('int')
# Out:
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END .........................................alpha=0.25; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................alpha=0.03333333333333333; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ............................................alpha=1; total time=   0.0s
# [CV] END ............................................alpha=2; total time=   0.0s
# [CV] END ............................................alpha=3; total time=   0.0s
# [CV] END ............................................alpha=3; total time=   0.0s
# [CV] END ..........................................alpha=200; total time=   0.0s
# [CV] END ..........................................alpha=300; total time=   0.0s
# [CV] END ..........................................alpha=400; total time=   0.0s
# [CV] END ..........................................alpha=900; total time=   0.0s
# [CV] END .........................................alpha=1000; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   9.2s
# [CV] END ............................................alpha=1; total time=   7.9s
# [CV] END ............................................alpha=3; total time=   7.7s
# [CV] END ............................................alpha=4; total time=   7.9s
# [CV] END ...........................................alpha=30; total time=   8.6s
# [CV] END ..........................................alpha=200; total time=   8.0s
# [CV] END ..........................................alpha=300; total time=   7.8s
# [CV] END ..........................................alpha=800; total time=   8.0s
# [CV] END ..........................................alpha=900; total time=   7.0s
# [CV] END ............................alpha=0.1, l1_ratio=0
1"><span class="toc-item-num">1&nbsp;&nbsp;</span>比赛背景</a></span></li><li><span><a href="#数据及具体目标" data-toc-modified-id="数据及具体目标-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>数据及具体目标</a></span></li><li><span><a href="#实施流程" data-toc-modified-id="实施流程-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>实施流程</a></span></li><li><span><a href="#代码实现" data-toc-modified-id="代码实现-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>代码实现</a></span><ul class="toc-item"><li><span><a href="#导入相关包" data-toc-modified-id="导入相关包-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>导入相关包</a></span></li><li><span><a href="#读取数据" data-toc-modified-id="读取数据-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>读取数据</a></span></li><li><span><a href="#数据预处理与特征工程" data-toc-modified-id="数据预处理与特征工程-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>数据预处理与特征工程</a></span><ul class="toc-item"><li><span><a href="#日期数据处理及特征类别转换" data-toc-modified-id="日期数据处理及特征类别转换-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>日期数据处理及特征类别转换</a></span></li><li><span><a href="#缺失值分析" data-toc-modified-id="缺失值分析-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>缺失值分析</a></span></li><li><span><a href="#异常值处理" data-toc-modified-id="异常值处理-4.3.3"><span class="toc-item-num">4.3.3&nbsp;&nbsp;</span>异常值处理</a></span></li><li><span><a href="#可视化分析" data-toc-modified-id="可视化分析-4.3.4"><span class="toc-item-num">4.3.4&nbsp;&nbsp;</span>可视化分析</a></span></li><li><span><a href="#目标变量分析" data-toc-modified-id="目标变量分析-4.3.5"><span class="toc-item-num">4.3.5&nbsp;&nbsp;</span>目标变量分析</a></span></li><li><span><a href="#运用随机森林模型填充-windspeed-特征中的零值" data-toc-modified-id="运用随机森林模型填充-windspeed-特征中的零值-4.3.6"><span class="toc-item-num">4.3.6&nbsp;&nbsp;</span>运用随机森林模型填充 windspeed 特征中的零值</a></span></li></ul></li><li><span><a href="#模型的建立与求解" data-toc-modified-id="模型的建立与求解-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>模型的建立与求解</a></span><ul class="toc-item"><li><span><a href="#准备数据" data-toc-modified-id="准备数据-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>准备数据</a></span></li><li><span><a href="#基本模型" data-toc-modified-id="基本模型-4.4.2"><span class="toc-item-num">4.4.2&nbsp;&nbsp;</span>基本模型</a></span><ul class="toc-item"><li><span><a href="#线性回归(LinearRegression)" data-toc-modified-id="线性回归(LinearRegression)-4.4.2.1"><span class="toc-item-num">4.4.2.1&nbsp;&nbsp;</span>线性回归(LinearRegression)</a></span></li><li><span><a href="#逻辑回归(LogisticRegression)" data-toc-modified-id="逻辑回归(LogisticRegression)-4.4.2.2"><span class="toc-item-num">4.4.2.2&nbsp;&nbsp;</span>逻辑回归(LogisticRegression)</a></span></li><li><span><a href="#套索回归(LassoRegression)" data-toc-modified-id="套索回归(LassoRegression)-4.4.2.3"><span class="toc-item-num">4.4.2.3&nbsp;&nbsp;</span>套索回归(LassoRegression)</a></span></li><li><span><a href="#岭回归(RidgeRegression)" data-toc-modified-id="岭回归(RidgeRegression)-4.4.2.4"><span class="toc-item-num">4.4.2.4&nbsp;&nbsp;</span>岭回归(RidgeRegression)</a></span></li><li><span><a href="#核岭回归(KernelRidge)" data-toc-modified-id="核岭回归(KernelRidge)-4.4.2.5"><span class="toc-item-num">4.4.2.5&nbsp;&nbsp;</span>核岭回归(KernelRidge)</a></span></li><li><span><a href="#弹性网络(ElasticNet)" data-toc-modified-id="弹性网络(ElasticNet)-4.4.2.6"><span class="toc-item-num">4.4.2.6&nbsp;&nbsp;</span>弹性网络(ElasticNet)</a></span></li><li><span><a href="#支持向量机(SVR,-Support-Vector-Regression)" data-toc-modified-id="支持向量机(SVR,-Support-Vector-Regression)-4.4.2.7"><span class="toc-item-num">4.4.2.7&nbsp;&nbsp;</span>支持向量机(SVR, Support Vector Regression)</a></span></li><li><span><a href="#K近邻回归(KNeighborsRegressor)" data-toc-modified-id="K近邻回归(KNeighborsRegressor)-4.4.2.8"><span class="toc-item-num">4.4.2.8&nbsp;&nbsp;</span>K近邻回归(KNeighborsRegressor)</a></span></li><li><span><a href="#决策树回归(DecisionTreeRegressor)" data-toc-modified-id="决策树回归(DecisionTreeRegressor)-4.4.2.9"><span class="toc-item-num">4.4.2.9&nbsp;&nbsp;</span>决策树回归(DecisionTreeRegressor)</a></span></li><li><span><a href="#极端随机树(ExtraTreesRegressor)" data-toc-modified-id="极端随机树(ExtraTreesRegressor)-4.4.2.10"><span class="toc-item-num">4.4.2.10&nbsp;&nbsp;</span>极端随机树(ExtraTreesRegressor)</a></span></li><li><span><a href="#装袋法(BaggingRegressor)" data-toc-modified-id="装袋法(BaggingRegressor)-4.4.2.11"><span class="toc-item-num">4.4.2.11&nbsp;&nbsp;</span>装袋法(BaggingRegressor)</a></span></li><li><span><a href="#随机森林(RandomForestRegressor)" data-toc-modified-id="随机森林(RandomForestRegressor)-4.4.2.12"><span class="toc-item-num">4.4.2.12&nbsp;&nbsp;</span>随机森林(RandomForestRegressor)</a></span></li><li><span><a href="#AdaBoost-(AdaBoostRegressor)" data-toc-modified-id="AdaBoost-(AdaBoostRegressor)-4.4.2.13"><span class="toc-item-num">4.4.2.13&nbsp;&nbsp;</span>AdaBoost (AdaBoostRegressor)</a></span></li><li><span><a href="#GBRT-(GradientBoostingRegressor)" data-toc-modified-id="GBRT-(GradientBoostingRegressor)-4.4.2.14"><span class="toc-item-num">4.4.2.14&nbsp;&nbsp;</span>GBRT (GradientBoostingRegressor)</a></span></li><li><span><a href="#XGBoost-(XGBRegressor)" data-toc-modified-id="XGBoost-(XGBRegressor)-4.4.2.15"><span class="toc-item-num">4.4.2.15&nbsp;&nbsp;</span>XGBoost (XGBRegressor)</a></span></li><li><span><a href="#LightGBM-(LGBMRegressor)" data-toc-modified-id="LightGBM-(LGBMRegressor)-4.4.2.16"><span class="toc-item-num">4.4.2.16&nbsp;&nbsp;</span>LightGBM (LGBMRegressor)</a></span></li></ul></li><li><span><a href="#模型融合-Stacking" data-toc-modified-id="模型融合-Stacking-4.4.3"><span class="toc-item-num">4.4.3&nbsp;&nbsp;</span>模型融合 Stacking</a></span></li><li><span><a href="#提交最终预测结果" data-toc-modified-id="提交最终预测结果-4.4.4"><span class="toc-item-num">4.4.4&nbsp;&nbsp;</span>提交最终预测结果</a></span></li></ul></li></ul></li></ul></div>
